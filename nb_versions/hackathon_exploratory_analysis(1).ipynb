# %% [markdown]
# # Loading datasets from local computer

# %%
# !pip install numpy pandas matplotlib ipywidgets

import os
from ipywidgets import interact
import seaborn as sb
import scipy.stats as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
owid_covid_data = pd.read_csv(r"/home/goncalo/Documents/cover/Illuminatti/hackathon/datasets/owid-covid-data.csv", index_col='location')

OxCGRT_covid_data = pd.read_csv(r"/home/goncalo/Documents/cover/Illuminatti/hackathon/datasets/OxCGRT_latest.csv", index_col='CountryName')
# Out:
# /home/goncalo/anaconda3/envs/hackathon/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
owid_covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83862 entries, Afghanistan to Zimbabwe
# Data columns (total 58 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               83862 non-null  object
#  1   continent                              79805 non-null  object
#  2   date                                   83862 non-null  object
#  3   total_cases                            81878 non-null  float64
#  4   new_cases                              81876 non-null  float64
#  5   new_cases_smoothed                     80875 non-null  float64
#  6   total_deaths                           72262 non-null  float64
#  7   new_deaths                             72420 non-null  float64
#  8   new_deaths_smoothed                    80875 non-null  float64
#  9   total_cases_per_million                81435 non-null  float64
#  10  new_cases_per_million                  81433 non-null  float64
#  11  new_cases_smoothed_per_million         80437 non-null  float64
#  12  total_deaths_per_million               71832 non-null  float64
#  13  new_deaths_per_million                 71990 non-null  float64
#  14  new_deaths_smoothed_per_million        80437 non-null  float64
#  15  reproduction_rate                      67668 non-null  float64
#  16  icu_patients                           8760 non-null   float64
#  17  icu_patients_per_million               8760 non-null   float64
#  18  hosp_patients                          10574 non-null  float64
#  19  hosp_patients_per_million              10574 non-null  float64
#  20  weekly_icu_admissions                  774 non-null    float64
#  21  weekly_icu_admissions_per_million      774 non-null    float64
#  22  weekly_hosp_admissions                 1273 non-null   float64
#  23  weekly_hosp_admissions_per_million     1273 non-null   float64
#  24  new_tests                              38228 non-null  float64
#  25  total_tests                            37944 non-null  float64
#  26  total_tests_per_thousand               37944 non-null  float64
#  27  new_tests_per_thousand                 38228 non-null  float64
#  28  new_tests_smoothed                     43803 non-null  float64
#  29  new_tests_smoothed_per_thousand        43803 non-null  float64
#  30  positive_rate                          42065 non-null  float64
#  31  tests_per_case                         41472 non-null  float64
#  32  tests_units                            45228 non-null  object
#  33  total_vaccinations                     8641 non-null   float64
#  34  people_vaccinated                      7932 non-null   float64
#  35  people_fully_vaccinated                5798 non-null   float64
#  36  new_vaccinations                       7318 non-null   float64
#  37  new_vaccinations_smoothed              13922 non-null  float64
#  38  total_vaccinations_per_hundred         8641 non-null   float64
#  39  people_vaccinated_per_hundred          7932 non-null   float64
#  40  people_fully_vaccinated_per_hundred    5798 non-null   float64
#  41  new_vaccinations_smoothed_per_million  13922 non-null  float64
#  42  stringency_index                       71095 non-null  float64
#  43  population                             83319 non-null  float64
#  44  population_density                     78061 non-null  float64
#  45  median_age                             75580 non-null  float64
#  46  aged_65_older                          74716 non-null  float64
#  47  aged_70_older                          75156 non-null  float64
#  48  gdp_per_capita                         75898 non-null  float64
#  49  extreme_poverty                        51698 non-null  float64
#  50  cardiovasc_death_rate                  76500 non-null  float64
#  51  diabetes_prevalence                    77600 non-null  float64
#  52  female_smokers                         59953 non-null  float64
#  53  male_smokers                           59068 non-null  float64
#  54  handwashing_facilities                 38437 non-null  float64
#  55  hospital_beds_per_thousand             69828 non-null  float64
#  56  life_expectancy                        79585 non-null  float64
#  57  human_development_index                76390 non-null  float64
# dtypes: float64(54), object(4)
# memory usage: 37.7+ MB

# %%
df = owid_covid_data.sort_values('date', ascending=True)
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
owid_covid_data.tail(20)
# Out:
#          iso_code continent        date  total_cases  new_cases  \
# location
# Zimbabwe      ZWE    Africa  2021-04-05      36934.0       11.0
# Zimbabwe      ZWE    Africa  2021-04-06      36966.0       32.0
# Zimbabwe      ZWE    Africa  2021-04-07      36984.0       18.0
# Zimbabwe      ZWE    Africa  2021-04-08      37052.0       68.0
# Zimbabwe      ZWE    Africa  2021-04-09      37147.0       95.0
# Zimbabwe      ZWE    Africa  2021-04-10      37273.0      126.0
# Zimbabwe      ZWE    Africa  2021-04-11      37288.0       15.0
# Zimbabwe      ZWE    Africa  2021-04-12      37307.0       19.0
# Zimbabwe      ZWE    Africa  2021-04-13      37330.0       23.0
# Zimbabwe      ZWE    Africa  2021-04-14      37369.0       39.0
# Zimbabwe      ZWE    Africa  2021-04-15      37422.0       53.0
# Zimbabwe      ZWE    Africa  2021-04-16      37534.0      112.0
# Zimbabwe      ZWE    Africa  2021-04-17      37699.0      165.0
# Zimbabwe      ZWE    Africa  2021-04-18      37751.0       52.0
# Zimbabwe      ZWE    Africa  2021-04-19      37859.0      108.0
# Zimbabwe      ZWE    Africa  2021-04-20      37875.0       16.0
# Zimbabwe      ZWE    Africa  2021-04-21      37980.0      105.0
# Zimbabwe      ZWE    Africa  2021-04-22      38018.0       38.0
# Zimbabwe      ZWE    Africa  2021-04-23      38045.0       27.0
# Zimbabwe      ZWE    Africa  2021-04-24      38064.0       19.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# location
# Zimbabwe              13.571        1525.0         0.0                0.714
# Zimbabwe              18.143        1531.0         6.0                1.571
# Zimbabwe              14.571        1531.0         0.0                1.143
# Zimbabwe              22.286        1532.0         1.0                1.286
# Zimbabwe              34.857        1535.0         3.0                1.571
# Zimbabwe              51.714        1538.0         3.0                2.000
# Zimbabwe              52.143        1538.0         0.0                1.857
# Zimbabwe              53.286        1542.0         4.0                2.429
# Zimbabwe              52.000        1543.0         1.0                1.714
# Zimbabwe              55.000        1548.0         5.0                2.429
# Zimbabwe              52.857        1550.0         2.0                2.571
# Zimbabwe              55.286        1551.0         1.0                2.286
# Zimbabwe              60.857        1552.0         1.0                2.000
# Zimbabwe              66.143        1553.0         1.0                2.143
# Zimbabwe              78.857        1553.0         0.0                1.571
# Zimbabwe              77.857        1554.0         1.0                1.571
# Zimbabwe              87.286        1555.0         1.0                1.000
# Zimbabwe              85.143        1555.0         0.0                0.714
# Zimbabwe              73.000        1556.0         1.0                0.714
# Zimbabwe              52.143        1556.0         0.0                0.571
#
#           total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# location                           ...
# Zimbabwe                 2484.975  ...        1899.775             21.4
# Zimbabwe                 2487.128  ...        1899.775             21.4
# Zimbabwe                 2488.339  ...        1899.775             21.4
# Zimbabwe                 2492.914  ...        1899.775             21.4
# Zimbabwe                 2499.306  ...        1899.775             21.4
# Zimbabwe                 2507.783  ...        1899.775             21.4
# Zimbabwe                 2508.793  ...        1899.775             21.4
# Zimbabwe                 2510.071  ...        1899.775             21.4
# Zimbabwe                 2511.618  ...        1899.775             21.4
# Zimbabwe                 2514.242  ...        1899.775             21.4
# Zimbabwe                 2517.808  ...        1899.775             21.4
# Zimbabwe                 2525.344  ...        1899.775             21.4
# Zimbabwe                 2536.445  ...        1899.775             21.4
# Zimbabwe                 2539.944  ...        1899.775             21.4
# Zimbabwe                 2547.210  ...        1899.775             21.4
# Zimbabwe                 2548.287  ...        1899.775             21.4
# Zimbabwe                 2555.351  ...        1899.775             21.4
# Zimbabwe                 2557.908  ...        1899.775             21.4
# Zimbabwe                 2559.725  ...        1899.775             21.4
# Zimbabwe                 2561.003  ...        1899.775             21.4
#
#           cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# location
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
# Zimbabwe                307.846                 1.82             1.6
#
#           male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# location
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
# Zimbabwe          30.7                  36.791                         1.7
#
#           life_expectancy  human_development_index
# location
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
# Zimbabwe            61.49                    0.571
#
# [20 rows x 58 columns]

# %%
df_filtered = df.loc['Netherlands']
# df_filtered.drop_duplicates(keep='first',inplace=True)

df_filtered.head()
# Out:
#             iso_code continent       date  total_cases  new_cases  \
# location
# Netherlands      NLD    Europe 2020-02-27          1.0        1.0
# Netherlands      NLD    Europe 2020-02-28          1.0        0.0
# Netherlands      NLD    Europe 2020-02-29          6.0        5.0
# Netherlands      NLD    Europe 2020-03-01         10.0        4.0
# Netherlands      NLD    Europe 2020-03-02         18.0        8.0
#
#              new_cases_smoothed  total_deaths  new_deaths  \
# location
# Netherlands                 NaN           NaN         NaN
# Netherlands                 NaN           NaN         NaN
# Netherlands                 NaN           NaN         NaN
# Netherlands                 NaN           NaN         NaN
# Netherlands                 NaN           NaN         NaN
#
#              new_deaths_smoothed  total_cases_per_million  ...  \
# location                                                   ...
# Netherlands                  NaN                    0.058  ...
# Netherlands                  NaN                    0.058  ...
# Netherlands                  NaN                    0.350  ...
# Netherlands                  NaN                    0.584  ...
# Netherlands                  NaN                    1.050  ...
#
#              gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# location
# Netherlands       48472.545              NaN                109.361
# Netherlands       48472.545              NaN                109.361
# Netherlands       48472.545              NaN                109.361
# Netherlands       48472.545              NaN                109.361
# Netherlands       48472.545              NaN                109.361
#
#              diabetes_prevalence  female_smokers  male_smokers  \
# location
# Netherlands                 5.29            24.4          27.3
# Netherlands                 5.29            24.4          27.3
# Netherlands                 5.29            24.4          27.3
# Netherlands                 5.29            24.4          27.3
# Netherlands                 5.29            24.4          27.3
#
#              handwashing_facilities  hospital_beds_per_thousand  \
# location
# Netherlands                     NaN                        3.32
# Netherlands                     NaN                        3.32
# Netherlands                     NaN                        3.32
# Netherlands                     NaN                        3.32
# Netherlands                     NaN                        3.32
#
#              life_expectancy  human_development_index
# location
# Netherlands            82.28                    0.944
# Netherlands            82.28                    0.944
# Netherlands            82.28                    0.944
# Netherlands            82.28                    0.944
# Netherlands            82.28                    0.944
#
# [5 rows x 58 columns]

# %%
with plt.style.context('fivethirtyeight'):
    df_filtered = df.loc['Netherlands']
    df_filtered.plot(x="date", y=["new_cases", "total_cases", "total_cases_per_million"])
    plt.xticks(rotation=90)
    plt.title('Plotting new cases, total cases and total cases per million in the Netherlands\n', size=15);
    plt.show()

# %%
# %matplotlib inline

plt.style.use('bmh')

fig = plt.subplots(figsize=(12, 8))

ax = sb.scatterplot(data=df, x='date', y='total_deaths', hue='continent')
ax.set_title('Scatterplot total deaths per continent', size=20);
ax.set_ylim(ymin=0)
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))

plt.legend(loc='upper left')
plt.setp(ax.get_xticklabels(), rotation=90)
print() # removes weird array output filled with 'None's

# %%
df = owid_covid_data.sort_values('date', ascending=True)

# Firstly need to change date time from string to datetime type
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

with plt.style.context('dark_background'):
    g = sb.lmplot('date', 'total_cases_per_million', data=df, hue='continent', fit_reg=False)
    ax = plt.gca()
    ax.set_title('Grid plot of total cases per continent', size=15);
    g.set(ylim=(0,None))
    g.set_xticklabels(rotation=90)
# Out:
# /home/goncalo/anaconda3/envs/hackathon/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Comparing total deaths and total cases per million
# We can see that even though the continent with the highest number of cases per million was Europe, America suffered many more deaths in total, particularly in the north.

# %%
# %matplotlib notebook

# 3d Visualization
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sb

sb.set(style = "darkgrid")

fig = plt.figure(figsize=(12,10))

ax = fig.add_subplot(111, projection = '3d')

x = df['total_deaths']
y = df['gdp_per_capita']
z = df['life_expectancy']

ax.set_xlabel("Total Deaths")
ax.set_ylabel("GDP")
ax.set_zlabel("Life Expectancy")

ax.scatter(x, y, z, c=y)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1199.3">

# %% [markdown]
# # Using the 3D graph to hypothesize about correlation
# It can be seen that lower GDPs and life expectancies are correlate as well as higher total number of deaths. So poorer countries with already low life expectancies suffered the larger number of total deaths.

# %%
owid_covid_data = pd.read_csv(r"/home/goncalo/Documents/cover/Illuminatti/hackathon/datasets/owid-covid-data.csv", index_col='continent')

df_europe = df.loc['Europe']
df_europe_date = df_europe.sort_values('date', ascending=True)
df_europe_date['date'] = pd.to_datetime(df_europe_date['date'], format = '%Y-%m-%d')
df_europe = df_europe_date

df_europe.tail()
# Out:
#           iso_code         location       date  total_cases  new_cases  \
# continent
# Europe         UKR          Ukraine 2021-04-24    2071142.0    12841.0
# Europe         SRB           Serbia 2021-04-24     677972.0     2068.0
# Europe         MKD  North Macedonia 2021-04-24     150274.0      564.0
# Europe         CHE      Switzerland 2021-04-24     646509.0        0.0
# Europe         ROU          Romania 2021-04-24    1044722.0     2201.0
#
#            new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# continent
# Europe              11711.714       43884.0       401.0              372.286
# Europe               2524.714        6196.0        32.0               34.571
# Europe                505.857        4650.0        22.0               33.000
# Europe               2015.714       10594.0        28.0               12.714
# Europe               2526.143       27267.0       154.0              170.714
#
#            total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# continent                           ...
# Europe                   47357.969  ...        7894.393              0.1
# Europe                   99634.424  ...       14048.881              NaN
# Europe                   72129.904  ...       13111.214              5.0
# Europe                   74701.044  ...       57410.166              NaN
# Europe                   54306.023  ...       23313.199              5.7
#
#            cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# continent
# Europe                   539.849                 7.11            13.5
# Europe                   439.415                10.08            37.7
# Europe                   322.688                10.08             NaN
# Europe                    99.739                 5.59            22.6
# Europe                   370.946                 9.74            22.9
#
#            male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# continent
# Europe             47.4                     NaN                       8.800
# Europe             40.2                  97.719                       5.609
# Europe              NaN                     NaN                       4.280
# Europe             28.9                     NaN                       4.530
# Europe             37.1                     NaN                       6.892
#
#            life_expectancy  human_development_index
# continent
# Europe               72.06                    0.779
# Europe               76.00                    0.806
# Europe               75.80                    0.774
# Europe               83.78                    0.955
# Europe               76.05                    0.828
#
# [5 rows x 58 columns]

# %%
# Create a pair plot colored by continent with a density plot of the # diagonal and format the scatter plots.
sb.pairplot(df_europe, hue = 'location', diag_kind = 'kde',
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
             size = 4)

# %%
# %matplotlib inline

grid = sb.FacetGrid(df_europe, col = "location", hue = "location", col_wrap=7)
grid.map(sb.scatterplot, "date", "total_deaths")

grid.add_legend()
plt.show()

# %%
fig = plt.subplots(figsize=(16, 14))

ax = sb.scatterplot(data = df_europe, x = "location", y = "gdp_per_capita", hue = "total_cases_per_million", size = "total_cases_per_million",
                   sizes=(100, 100000), legend='full')
ax.set_title('Scatterplot GDP per , where datapoint size represents total number of cases', size=20);
ax.set_ylim(ymin=0)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

plt.legend([],[], frameon=False)
plt.setp(ax.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# # Estimating the correlation between two variables with a contingency table and a chi-squared test
#
# Estimating correlation between total_deaths and cardiovasc death rate, diabetes prevalence, female and male smokers.

# %%
# Select latest available data
df_europe = df_europe.loc[df_europe['date'] == '2021-04-24']

countries = df_europe['location']
total_deaths = df_europe['total_deaths']
diabetes = df_europe['diabetes_prevalence']
cvd_rate = df_europe['cardiovasc_death_rate']
n_smokers = df_europe['female_smokers'] + df_europe['male_smokers']

# %%
df_bis_diabetes = pd.DataFrame({'country':countries,
                       'total_deaths': total_deaths,
                       'diabetes': diabetes}).dropna()

df_bis_cvd_rate = pd.DataFrame({'country':countries,
                       'total_deaths': total_deaths,
                       'cvd_rate': cvd_rate}).dropna()

df_bis_smoking = pd.DataFrame({'country':countries,
                       'total_deaths': total_deaths,
                       'n_smokers': n_smokers}).dropna()

df_bis_diabetes = df_bis_diabetes.reset_index(drop=True)
df_bis_cvd_rate = df_bis_cvd_rate.reset_index(drop=True)
df_bis_smoking = df_bis_smoking.reset_index(drop=True)


df_bis_diabetes.set_index(["country"], inplace = True,
                    append = True, drop = True)
df_bis_cvd_rate.set_index(["country"], inplace = True,
                    append = True, drop = True)
df_bis_smoking.set_index(["country"], inplace = True,
                    append = True, drop = True)

df_bis_diabetes.head(39)
# Out:
#                            total_deaths  diabetes
#    country
# 0  Hungary                      26420.0      7.55
# 1  Spain                        77591.0      7.17
# 2  France                      102872.0      4.77
# 3  Luxembourg                     790.0      4.42
# 4  Iceland                         29.0      5.31
# 5  Greece                        9950.0      4.55
# 6  Norway                         736.0      5.31
# 7  Bulgaria                     15859.0      5.81
# 8  Belarus                       2483.0      5.18
# 9  Latvia                        2101.0      4.91
# 10 Liechtenstein                   57.0      7.77
# 11 Poland                       65222.0      5.91
# 12 Czechia                      28920.0      6.82
# 13 Albania                       2372.0     10.08
# 14 Estonia                       1137.0      4.02
# 15 Ireland                       4872.0      3.28
# 16 Andorra                        124.0      7.97
# 17 San Marino                      89.0      5.64
# 18 Montenegro                    1463.0     10.08
# 19 Lithuania                     3841.0      3.67
# 20 Austria                      10070.0      6.35
# 21 Denmark                       2475.0      6.41
# 22 Moldova                       5709.0      5.72
# 23 Portugal                     16959.0      9.85
# 24 Bosnia and Herzegovina        8203.0     10.08
# 25 Slovenia                      4203.0      7.25
# 26 Netherlands                  17269.0      5.29
# 27 Belgium                      23990.0      4.29
# 28 Cyprus                         298.0      9.24
# 29 Malta                          412.0      8.83
# 30 Slovakia                     11458.0      7.29
# 31 United Kingdom              127670.0      4.28
# 32 Croatia                       6815.0      5.59
# 33 Sweden                       13923.0      4.79
# 34 Russia                      106108.0      6.18
# 35 Monaco                          31.0      5.46
# 36 Italy                       119021.0      4.78
# 37 Germany                      81610.0      8.31
# 38 Finland                        903.0      5.76

# %% [markdown]
# # Pearson's correlation coefficient

# %%
df_bis_diabetes.corr()
# Out:
#               total_deaths  diabetes
# total_deaths      1.000000 -0.158048
# diabetes         -0.158048  1.000000

# %%
df_bis_cvd_rate.corr()
# Out:
#               total_deaths  cvd_rate
# total_deaths      1.000000 -0.120867
# cvd_rate         -0.120867  1.000000

# %%
df_bis_smoking.corr()
# Out:
#               total_deaths  n_smokers
# total_deaths      1.000000   0.018405
# n_smokers         0.018405   1.000000

# %% [markdown]
# # contingency table, with the frequencies of all four possibilities

# %%
df_bis_diabetes['total_deaths_binarized'] = (df_bis_diabetes['total_deaths'] > df_bis_diabetes['total_deaths'].median())
df_bis_diabetes['diabetes_binarized'] = (df_bis_diabetes['diabetes'] > df_bis_diabetes['diabetes'].median())

pd.crosstab(df_bis_diabetes['total_deaths_binarized'], df_bis_diabetes['diabetes_binarized'])
# Out:
# diabetes_binarized      False  True
# total_deaths_binarized
# False                      12     10
# True                       10     12

# %%
df_bis_cvd_rate['total_deaths_binarized'] = (df_bis_cvd_rate['total_deaths'] > df_bis_cvd_rate['total_deaths'].median())
df_bis_cvd_rate['cvd_binarized'] = (df_bis_cvd_rate['cvd_rate'] > df_bis_cvd_rate['cvd_rate'].median())

pd.crosstab(df_bis_cvd_rate['total_deaths_binarized'], df_bis_cvd_rate['cvd_binarized'])
# Out:
# cvd_binarized           False  True
# total_deaths_binarized
# False                      10     11
# True                       11      9

# %%
df_bis_smoking['total_deaths_binarized'] = (df_bis_smoking['total_deaths'] > df_bis_smoking['total_deaths'].median())
df_bis_smoking['n_smokers_binarized'] = (df_bis_smoking['n_smokers'] > df_bis_smoking['n_smokers'].median())

pd.crosstab(df_bis_smoking['total_deaths_binarized'], df_bis_smoking['n_smokers_binarized'])
# Out:
# n_smokers_binarized     False  True
# total_deaths_binarized
# False                      11      9
# True                        9     11

# %%
# Example of funtion for displaying tables neatly
from IPython.display import display_html
from itertools import chain,cycle

def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2>{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)
    
    
tab1 = pd.crosstab(df_bis['total_deaths_binarized'], df_bis['diabetes_binarized'])
tab2 = pd.crosstab(df_bis['total_deaths_binarized'], df_bis['cvd_rate_binarized'])
tab3 = pd.crosstab(df_bis['total_deaths_binarized'], df_bis['n_smokers_binarized'])

display_side_by_side(tab1, tab2, tab3, titles=['deaths / diabetes', 'deaths / cvd rate', 'deaths / n smokers'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>deaths / diabetes</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>diabetes_binarized</th>
#       <th>False</th>
#       <th>True</th>
#     </tr>
#     <tr>
#       <th>total_deaths_binarized</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>11</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>deaths / cvd rate</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>cvd_rate_binarized</th>
#       <th>False</th>
#       <th>True</th>
#     </tr>
#     <tr>
#       <th>total_deaths_binarized</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>11</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>deaths / n smokers</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>n_smokers_binarized</th>
#       <th>False</th>
#       <th>True</th>
#     </tr>
#     <tr>
#       <th>total_deaths_binarized</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>11</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# # To determine if there is a statistically significant correlation between the variables -> chi-squared test

# %%
from IPython.display import display_html

this = pd.crosstab(df_bis_diabetes['total_deaths_binarized'], df_bis['diabetes_binarized'])
st.chi2_contingency(this)
# Out:
# (0.625,
#  0.42919530044034926,
#  1,
#  array([[4., 1.],
#         [4., 1.]]))

# %%
this = pd.crosstab(df_bis_diabetes['total_deaths_binarized'], df_bis['diabetes_binarized'])
st.chi2_contingency(this)

# %%
this = pd.crosstab(df_bis_diabetes['total_deaths_binarized'], df_bis['diabetes_binarized'])
st.chi2_contingency(this)

# %%
OxCGRT_covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135161 entries, Aruba to Zimbabwe
# Data columns (total 50 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   CountryCode                            135161 non-null  object
#  1   RegionName                             45695 non-null   object
#  2   RegionCode                             45695 non-null   object
#  3   Jurisdiction                           135161 non-null  object
#  4   Date                                   135161 non-null  int64
#  5   C1_School closing                      131038 non-null  float64
#  6   C1_Flag                                104165 non-null  float64
#  7   C2_Workplace closing                   130851 non-null  float64
#  8   C2_Flag                                97175 non-null   float64
#  9   C3_Cancel public events                130910 non-null  float64
#  10  C3_Flag                                104274 non-null  float64
#  11  C4_Restrictions on gatherings          130883 non-null  float64
#  12  C4_Flag                                97742 non-null   float64
#  13  C5_Close public transport              130564 non-null  float64
#  14  C5_Flag                                57102 non-null   float64
#  15  C6_Stay at home requirements           130566 non-null  float64
#  16  C6_Flag                                84993 non-null   float64
#  17  C7_Restrictions on internal movement   130545 non-null  float64
#  18  C7_Flag                                78023 non-null   float64
#  19  C8_International travel controls       129647 non-null  float64
#  20  E1_Income support                      128235 non-null  float64
#  21  E1_Flag                                74777 non-null   float64
#  22  E2_Debt/contract relief                128092 non-null  float64
#  23  E3_Fiscal measures                     104665 non-null  float64
#  24  E4_International support               104704 non-null  float64
#  25  H1_Public information campaigns        130616 non-null  float64
#  26  H1_Flag                                118562 non-null  float64
#  27  H2_Testing policy                      130404 non-null  float64
#  28  H3_Contact tracing                     130252 non-null  float64
#  29  H4_Emergency investment in healthcare  104501 non-null  float64
#  30  H5_Investment in vaccines              104628 non-null  float64
#  31  H6_Facial Coverings                    128794 non-null  float64
#  32  H6_Flag                                93731 non-null   float64
#  33  H7_Vaccination policy                  111822 non-null  float64
#  34  H7_Flag                                20720 non-null   float64
#  35  H8_Protection of elderly people        129002 non-null  float64
#  36  H8_Flag                                87411 non-null   float64
#  37  M1_Wildcard                            0 non-null       float64
#  38  ConfirmedCases                         123748 non-null  float64
#  39  ConfirmedDeaths                        123639 non-null  float64
#  40  StringencyIndex                        130529 non-null  float64
#  41  StringencyIndexForDisplay              131389 non-null  float64
#  42  StringencyLegacyIndex                  130538 non-null  float64
#  43  StringencyLegacyIndexForDisplay        131397 non-null  float64
#  44  GovernmentResponseIndex                128795 non-null  float64
#  45  GovernmentResponseIndexForDisplay      129663 non-null  float64
#  46  ContainmentHealthIndex                 130424 non-null  float64
#  47  ContainmentHealthIndexForDisplay       131292 non-null  float64
#  48  EconomicSupportIndex                   128029 non-null  float64
#  49  EconomicSupportIndexForDisplay         128887 non-null  float64
# dtypes: float64(45), int64(1), object(4)
# memory usage: 52.6+ MB

# %%
OxCGRT_covid_data.tail(20)
# Out:
#             CountryCode RegionName RegionCode Jurisdiction      Date  \
# CountryName
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210406
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210407
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210408
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210409
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210410
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210411
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210412
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210413
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210414
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210415
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210416
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210417
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210418
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210419
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210420
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210421
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210422
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210423
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210424
# Zimbabwe            ZWE        NaN        NaN    NAT_TOTAL  20210425
#
#              C1_School closing  C1_Flag  C2_Workplace closing  C2_Flag  \
# CountryName
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   2.0      1.0
# Zimbabwe                   1.0      1.0                   NaN      NaN
#
#              C3_Cancel public events  ...  StringencyIndex  \
# CountryName                           ...
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            57.41
# Zimbabwe                         2.0  ...            51.85
# Zimbabwe                         2.0  ...            51.85
# Zimbabwe                         2.0  ...            51.85
# Zimbabwe                         2.0  ...            51.85
# Zimbabwe                         2.0  ...            51.85
# Zimbabwe                         2.0  ...            51.85
# Zimbabwe                         2.0  ...              NaN
#
#              StringencyIndexForDisplay  StringencyLegacyIndex  \
# CountryName
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         57.41                  70.24
# Zimbabwe                         51.85                  60.71
# Zimbabwe                         51.85                  60.71
# Zimbabwe                         51.85                  60.71
# Zimbabwe                         51.85                  60.71
# Zimbabwe                         51.85                  60.71
# Zimbabwe                         51.85                  60.71
# Zimbabwe                         51.85                    NaN
#
#              StringencyLegacyIndexForDisplay  GovernmentResponseIndex  \
# CountryName
# Zimbabwe                               70.24                    48.23
# Zimbabwe                               70.24                    48.23
# Zimbabwe                               70.24                    48.23
# Zimbabwe                               70.24                    48.23
# Zimbabwe                               70.24                    48.23
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               70.24                    52.40
# Zimbabwe                               60.71                    49.27
# Zimbabwe                               60.71                    49.27
# Zimbabwe                               60.71                    49.27
# Zimbabwe                               60.71                    49.27
# Zimbabwe                               60.71                    49.27
# Zimbabwe                               60.71                    49.27
# Zimbabwe                               60.71                      NaN
#
#              GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# CountryName
# Zimbabwe                                 48.23                   55.12
# Zimbabwe                                 48.23                   55.12
# Zimbabwe                                 48.23                   55.12
# Zimbabwe                                 48.23                   55.12
# Zimbabwe                                 48.23                   55.12
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 52.40                   59.88
# Zimbabwe                                 49.27                   56.31
# Zimbabwe                                 49.27                   56.31
# Zimbabwe                                 49.27                   56.31
# Zimbabwe                                 49.27                   56.31
# Zimbabwe                                 49.27                   56.31
# Zimbabwe                                 49.27                   56.31
# Zimbabwe                                 49.27                     NaN
#
#              ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# CountryName
# Zimbabwe                                55.12                   0.0
# Zimbabwe                                55.12                   0.0
# Zimbabwe                                55.12                   0.0
# Zimbabwe                                55.12                   0.0
# Zimbabwe                                55.12                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                59.88                   0.0
# Zimbabwe                                56.31                   0.0
# Zimbabwe                                56.31                   0.0
# Zimbabwe                                56.31                   0.0
# Zimbabwe                                56.31                   0.0
# Zimbabwe                                56.31                   0.0
# Zimbabwe                                56.31                   0.0
# Zimbabwe                                56.31                   0.0
#
#              EconomicSupportIndexForDisplay
# CountryName
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
# Zimbabwe                                0.0
#
# [20 rows x 50 columns]

# %% [markdown]
# # Simple plot

# %% [markdown]
# # More interesting notebooks
#
# ## Javascript-based visualization that maps data to countries in an interactie image
# https://towardsdatascience.com/data-analysis-and-visualization-with-jupyter-notebook-22f6dcd25cc5
#
# ## Machine Learning notebooks
# https://machine-learning-with-python.readthedocs.io/en/latest/
